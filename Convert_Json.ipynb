# %%
import geopandas as gpd

gpd.read_file("layers/BB3.geojson",driver = 'geojson')
# Out:
#     OBJECTID  FID_Chambers_2016_Burn_Merge       Site  Plot        Status  \
# 0          1                            11  2005 Fire  PSLS  Eestablished
# 1          2                            12  2005 Fire  PSLS  Eestablished
# 2          3                             9  2005 Fire  PSLS  Eestablished
# 3          4                            10  2005 Fire  PSLS  Eestablished
# 4          5                            20  2005 Fire   PSW  Eestablished
# 5          6                            19  2005 Fire   PSW  Eestablished
# 6          7                            18  2005 Fire   PSW  Eestablished
# 7          8                            17  2005 Fire   PSW  Eestablished
# 8          9                            15  2005 Fire  PSTS  Eestablished
# 9         10                            14  2005 Fire  PSTS  Eestablished
# 10        11                            16  2005 Fire  PSTS  Eestablished
# 11        12                            13  2005 Fire  PSTS  Eestablished
# ...
